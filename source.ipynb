# %%
# %sql

drop table if exists data_modeling.default.customers;
CREATE TABLE if not exists data_modeling.default.customers (
    customer_id INT PRIMARY KEY,
    first_name VARCHAR(100),
    last_name VARCHAR(100),
    email VARCHAR(150),
    phone_number VARCHAR(20),
    date_joined DATE
);

# %%
# %sql
INSERT INTO data_modeling.default.customers
(customer_id, first_name, last_name, email, phone_number, date_joined)
VALUES
(2, 'Amit', 'Patil', 'amit.patil@gmail.com', '9876543211', '2026-09-26'),
(3, 'Sneha', 'Sharma', 'sneha.sharma@gmail.com', '9876543212', '2026-09-27'),
(4, 'Vikas', 'Joshi', 'vikas.joshi@gmail.com', '9876543213', '2026-09-28'),
(5, 'Priya', 'Deshmukh', 'priya.deshmukh@gmail.com', '9876543214', '2026-09-29');
